# %% [markdown]
# # Example of searching a folder for variations on a set of terms
#
# Suppose we want to find variations of the word "purpose" in a set of texts.
#
# We have a folder where the texts are stored:

# %%
source = '/Users/tunder/Box Sync/NEHproject/dirtynarratives/'

# %% [markdown]
# And a list of words we want to get:

# %%
# making this a set because it's fast to check membership in a set

targets = {'purpose', 'purposive', 'purposed'}

# %% [markdown]
# We could start by getting a list of files to search. To limit the task, I'm going to arbitrarily say only those beginning with "9" or "8".

# %%
import glob
files2get = glob.glob(source + '9*.txt')
files2get.extend(glob.glob(source + '8*.txt'))
len(files2get)
# Out:
# 17

# %% [markdown]
# Some modules that will come in handy.

# %%
from difflib import SequenceMatcher
from nltk import tokenize

# %%
snippets = []

for filename in files2get:
    with open(filename, encoding = 'utf-8') as f:
        filestring = f.read()
    wordsinfile = tokenize.word_tokenize(filestring)
    
    for idx, w in enumerate(wordsinfile):
        found = False
        if w in targets:
            found = True
            w = w.lower()
        elif w.startswith('p') and len(w) > 4:
            # suspicious!
            # you might not have an easy way to filter candidates like this,
            # but in this case we do. Otherwise just proceed to the next step.
            
            for t in targets:
                matcher = SequenceMatcher(None, w, t)
                if matcher.real_quick_ratio() > 0.5 and matcher.ratio() > 0.85:  # the quick check happens first
                    found = True                            # and saves us some time by blocking obvious fails
                    break
        
        if found:
            snippetstart = idx - 20
            if snippetstart < 0:
                snippetstart = 0
            
            snippetend = idx + 20
            if snippetend > len(wordsinfile):
                snippetend = len(wordsinfile)
            
            snippets.append((filename, idx, ' '.join(wordsinfile[snippetstart : snippetend])))
            if len(snippets) % 10 == 1:
                print(len(snippets))
# Out:
# 1
# 11
# 21
# 31
# 41
# 51
# 61
# 71

# %% [markdown]
# The counting from 1 to 71 above isn't important here, but in a long task it gives you a way to know the program is running and not broken.
#
# In the examples below, you'll see our criteria are a bit over-generous; we got some examples of "propose," which was close enough to "purpose" to slide under the .85 threshold. But if the overall number of hits is likely to be low it might be wiser to be generous — and catch "purpoſe" — than to be too stingy.

# %%
snippets
# Out:
# [('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9611_4.txt',
#   15174,
#   "Phyſiognomiſt will . • rarely be deceived . I preſume you have never read the Story of Socrates to this purpoſe , and '' therefore I will tell it you . A certain Phyſiog- 'romiſt aſſerted of Socrates , that"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9611_2.txt',
#   8239,
#   "far off ? The Mug is out , ſhall I draw another ? '' Whilft he was gone for that purpoſe , a Stage- Coach drove up to the Door . The Coachman coming into the Houſe , was aſked"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9611_3.txt',
#   5448,
#   'he was no ſooneř arrived , than Bellar- mine brought him back to the Point ; but all to no purpoſe ; he made his Eſcape from that Subject in : in a Minute ; till at laſt the Lover'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9611_0.txt',
#   7176,
#   'Shillings por Annum would have accrued to the Rector : but he had not yet been able to accompliſh his purpoſe ; and had reap- ed hitherto nothing better from the Suits than the Pleaſure ( which he uſed indeed'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9609_3.txt',
#   3768,
#   "order- ing his Man to produce a Cloak-bag which he had cauſed to be brought from Lady Booby 's on purpoſe , he deſired the Juſtice that he might have Jofeph with him into a Room ; where or dering"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/9609_3.txt',
#   12923,
#   'theſe , name- ly , Impatience . Now , Child , I muſt inform you , that if in your purpoſed Marriage with young Woman , you have no Intention but • the Indulgence of carnal Appetites , you are'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   229,
#   'instruction to the heart , that are peculiar to ourselves , are equally numerous and inexhaustible . It is the purpose of this work to profit by some of these sources ; to exhibit a series of adventures , growing'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   543,
#   'passing or approaching ; to forbear to grasp at futurity ; to suffer so much thought to wander from the purpose which engrossed my fears and my hopes , could not be . I sure that even now , my'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   1620,
#   'duty and discretion . Remembrances bad ceased to agonize , to urge me to headlong acts , and foster sanguinary purposes . The gloom was half dispersed , and a radiance had succeeded sweeter than my former joys . Now'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   2681,
#   'soul . His occupation was mysterious and obscure . Was it a grave that he was digging ? Was his purpose to explore or to hide ? Was it proper to watch him at a distance , unobserved and in'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   4394,
#   'the agents and instigators of the murder of my friend . But it suddenly occurred to me , for what purpose shall I prosecute this search ? What benefit am I to reap from this discovery ? How shall I'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   4644,
#   'undisciplined by reason , and inconducive to benefit . I was not , however , to be diverted from my purpose . Curiosity , like virtue , is its own reward . Knowledge is of value for its own sake'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   4980,
#   '. Why should I proceed like a plotter ? Do I intend the injury of this person ? A generous purpose will surely . excuse me from descending to artifices ? There are two modes of drawing forth the secrets'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   5047,
#   ', and state my doubts , and demand a solution of them , in a manner worthy of a beneficent purpose ? Why not hasten 16 to the spot ? He may be , at this moment , mysteriously occupied'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   7569,
#   'conclusion . He and his fellow servant occupied an apartment in the barn as a lodging room . This arduous purpose was accomplished , and I retired to the shelter of a neighboring shed , not so much to repose'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   9452,
#   ', was to bear him company , and seize some oppor- tunity , during this interval , of effecting my purpose . I told him , that since he would not remain , I cared not if , for the'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   9701,
#   '; yet , if I intended not the conferring of a benefit , I did not , at least , purpose the infliction of evil . I persuaded myself , that I was able to exclude from my bosom ,'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   10165,
#   'suspense . There is a tale connected with it , which I am desirous of telling you . For this purpose I have brought you hither . Listen to me . I then recapitulated the adventures of the two preceding'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   11614,
#   "him , and he hastened to inform me , that he was coming to my uncle 's , for the purpose of meeting and talking with me . If I thought proper , we would go into the wood together"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   11945,
#   "tions , you may be sure of my compliance . I could resist every demand but this . For what purpose , have I ' come hither ? Is it to relate my story ? Shall I calmly sit here"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   13942,
#   'as a new proof of the inflexible consistency of my principles . On this change in my situation , she proposed to me to become a member of her own family . No proposal could be more acceptable . I'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   14981,
#   'generosity of her cha- racter . Her hours were distributed with the utmost regularity , and appropriated to the best purposes . She selected her society without regard to any qualities but probity and talents . Her associates were numerous'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   15563,
#   'nothing to external circumstances ; in what different modes the same materials may be fashioned , and to what different purposes the same materials may be applied . Perhaps the rudiments of their intellectual character as well as of their'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_0.txt',
#   15616,
#   "case were exerted in the cause of virtue , were , in the other , misapplied to sordid and fagitious purposes . Arthur Wiatte , that was his name , had ever been the object of his sister 's affection"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   2413,
#   'me from her presence and service . But should I ultimately resolve to separate , how should I communicate my purpose . The pain of part- ing would scarcely be less on her side than on mine . Could I'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   2800,
#   '. I admitted any excuse for postponing my design , and gladly admitted any topic , however foreign to my purpose . It must not be imagined that my health sustained no injury from this conflict of my passions .'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   3967,
#   'The lady was overwhelmed with sweet confusion . Averted eyes and reluctant steps , might have explained to me the purpose of this meeting , if I had be- lieved that purpose to be possible . I felt the necessity'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   3978,
#   'reluctant steps , might have explained to me the purpose of this meeting , if I had be- lieved that purpose to be possible . I felt the necessity of must go 49 new fortitude , and struggled to recollect'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   5047,
#   'prolong her absence beyond a month . When I bade her farewell , and informed her on what day I proposed to return for her , I felt no decay of my satis- faction . My thoughts were bright and'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   6994,
#   'You may , of course , rely upon my assistance and advice . What is it that you have to propose ? Tuesday evening , he answered , I spent here . It was late before I returned to my'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   7486,
#   ', I know not . I thought , however , 57 of one expedient . It might serve a present purpose , and something better might suggest itself on your return . I came hither early the next day .'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   9025,
#   '. It was the amount of a debt which had lately been recovered . It was lodged here for the purpose of being paid on demand of her or her agents . It was my present business to receive this'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   14065,
#   'evil ? Is the province assigned me that of an infernal emissary , whose efforts are concentred in a single purpose and that purpose a malignant one ? I am the author of thy calami- ties . Whatever misery is'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   14068,
#   'the province assigned me that of an infernal emissary , whose efforts are concentred in a single purpose and that purpose a malignant one ? I am the author of thy calami- ties . Whatever misery is reserved for thee'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   14471,
#   'to this extremity of horror that my evil genius was determined to urge me ? Too surely this was his purpose ; too surely I was qualified to be its minister . I lifted the weapon . Its point was'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_1.txt',
#   14611,
#   'deed , that started into being and activity at a moment so pregnant with fate , without tokens of his purpose or his coming being previously imparted , could not , methought , be less than divinity . The first'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   1532,
#   'could not be more usefully employed than in making my intended copy . In a few hours after sunrise I purposed to resume my way to the mountain . Could this interval be appropriated to a better purpose than in'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   1549,
#   "after sunrise I purposed to resume my way to the mountain . Could this interval be appropriated to a better purpose than in counting over my friend 's letters , setting them apart from my own , and preparing them"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   1585,
#   ', and preparing them for that transcription from which I expected so high and yet so mournful a gratification . purpose , by no violent union , was blended with recollection of my dream . This recollection infused some degree'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   1638,
#   'I should violate pathetic and solemn in- junctions frequently repeated by the writer . Was there some connexon between this purpose and the incidents of my vision . Was the latter sent to enforce the interdictions which had been formerly'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   2875,
#   'remained ? This invaluable relic had disappear- ed . Every thought and every effort must be devoted to the single purpose of regaining it . As yet I did not despair . Until I had opened and ransacked every part'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   4875,
#   'door . I started from my seat , and , going forth , waited with some impatience to hear his purpose ex : plained . 121 voice ; He accosted me with the formality of a stranger , and asked'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   7382,
#   'of Scottish or French physicians , whom I expected to meet with in that city . I adhered to my purpose with so much vehemence and obstinacy , that they finally yielded to my wishes . My road lay through'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   7480,
#   '. They were knavish and inhuman , and omitted nothing , but actual violence to hasten my death . They purposely retarded the journey , and protracted to seven , what might have been readily per- formed in four days'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_3.txt',
#   11656,
#   'They were useless paper , and might , without impropriety , be cast away or made to serve any temporary purpose . Perhaps , indeed , they still lurk in some unsuspected corner . To wish that time may explain'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   650,
#   "of affluence , and assumed a beggar's attire . That I had money about me for the accomplishment of my purposes was wholly accidental . I travelled along the coast , and when I arrived at one town , knew"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   2460,
#   'his journey , and his present situation , he professed himself in search of lucrative employ- ment . My uncle proposed to him to become a teacher , there being a sufficient number of young people in this neigh- borhood'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   3819,
#   ', winding and abrupt , leads into the midst of this region and through it . This vale serves the purpose of a road . It is a tedious maze , and perpetual declivity , and requires , from the'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   3950,
#   'and nuts , or led by a roaming disposition . Afterwards the sphere of my rambles was enlarged and their purpose changed . When Sarsefield came among us , I became his favorite scholar and the companion of all his'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   4441,
#   ', when the attempt was made , though viewed at a distance they seemed to be too narrow for that purpose . As I descended the rugged stair , I could not but wonder at the temerity and precipitation with'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   5043,
#   'undertaking on the morrow . Yet , having advanced thus far , I felt reluctance to recede without accomplishing my purposes . I reflected likewise 87 that Clithero had boldly entered this recess , and had cer- tainly come forth'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   7653,
#   'could not fail to be of benign influence . These thoughts inspired me with new zeal . To effect my purpose it was requisite to reach the opposite steep . I was now convinced that this was not an impracticable'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   9646,
#   'pected and extraordinary , might suggest new thoughts , and be construed into a kind of heavenly condemnation of his purpose . He would not readily suspect the motives or person of his visitant , would take no precaution against'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   10176,
#   "chamber . When the family were all retired , and there was no fear of observation or interruption , I proposed to rise and hasten , with a proper implement , hither . One chamber , in Inglefield 's house"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   11321,
#   'its parts appeared equally solid and smooth . It could not be doubted that one of its sides served the purpose of a lid , and was possible to be raised . Mere strength could not be applied to raise'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   13234,
#   'This did not deter me from visiting the mountain . Slippery paths and muddy torrents were no obstacles to the purposes which I had adopted . I wrapt myself , and a bag of pro- visions , in a cloak'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_2.txt',
#   13986,
#   'the essential characteristics of rior in size and strength , these are such ble to man . 106 1 The purpose of this arduous journey was defeated , by the loss of the provisions I had brought . I despaired'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   4594,
#   'he meant to murder stood near , saw the lifted weapon , and heard him confess and glory in his purposes . No wonder that the shock bereft her , for a time , of life . The interval was'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   5437,
#   'it possible to bring them together ; to win the maniac from his solitude , wrest from him his fatal purposes , and restore him to com- munion with the beings whose imagined indignation is the torment of his life'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   7596,
#   "of my being I hastened to Inglefield 's by night . There was no need to warn him of my purpose . I desired that my fate should be an eternal secret to my ancient master and his neighbors ."),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   7661,
#   'its treasure . My transports of astonishment , and indignation , and grief yielded to the resumption of my fatal purpose . I hastened back to the hill , and determined anew to perish . This mood continued to the'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   10906,
#   'his journey into Virginia , from which he had somewhat devi- ated , in order to visit Solebury . He proposed to return in less than a month , and then to take me in his company to New York'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   11062,
#   'the event proved him to be . I was punctu- ally informed of the progress of his cure , and proposed in a few days to visit him . The duty of explaining the truth , respecting the present condition'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   13368,
#   'seemed preparing to withdraw . I was anxiously attentive to his demeanor , and as soon as I perceived his purpose to depart , leaped on my feet to 248 mu- prevent it . I took his hand , and'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   13459,
#   'I seated myself near him , and a pause of tual silence ensued . My mind was full of the purpose that brought me hither , but I knew not in what manner to communicate my purpose . Several times'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   13475,
#   'was full of the purpose that brought me hither , but I knew not in what manner to communicate my purpose . Several times I opened my lips to speak , but my perplexity continued , and suitable words refused'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   14502,
#   'What must it be when he starts up before her in his neglected and ferocious guise , and armed with purposes , perhaps as terrible as those , which had formerly led him to her secret chamber , and her'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_6.txt',
#   15082,
#   'setting out on her voyage . 252 This vessel I engaged to wait a day or two , for the purpose of conveying him to Pennsylvania hospital . Meanwhile , proper persons were stationed at Powles-hook , and at the'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   3057,
#   'uneven , and the posture I was obliged to assume , unnatural and painful . It was evident that my purpose could not be answered by remaining here . I , therefore , crept forth , and began to reflect'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   3681,
#   'hesitation vanished , and plac- ing my tomahawk and fusil upon the ground , I prepared to leap . This purpose was suspended , in the moment of its ex- ecution , by a faint sound , heard from the'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   5113,
#   'were necessary to re- cross the river , to lay in a stock of recruited spirits and strength for that purpose . I trusted that the water would 193 speedily become shoal , or that the steep would afford rest'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   5198,
#   'been enormous , and my clothes , heavy with moisture , greatly encumbered and retarded my movements . I had proposed to free my- self from this imprisonment , but I foresaw the inconveniences of wandering over this scene in'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   6794,
#   '. The last spark of fire as put out , so that had my cu- riosity been idle , my purpose could not be accomplished . To retire from this scene , neither curiosity nor benevolence would permit . That'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_5.txt',
#   15791,
#   'pupil , was the same by which we must trace or intercept the retreat of the savages . Thus two purposes , equally momentous , would be answered by the same means . Mr. Huntly armed himself with your fusil'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_4.txt',
#   4055,
#   "rush forward to secure the road which my adversary's death would open to me ? Perhaps you will conceive a purpose like this to have ar- gued a sanguinary and murderous disposition . ' Let it be remembered , however"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_4.txt',
#   7658,
#   'the legacy of an English officer , who died in Bengal , to Sarsefield . It was constructed for the purposes not of sport but of war . The artist had made it a congeries of tubes and springs ,'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_4.txt',
#   7681,
#   "sport but of war . The artist had made it a congeries of tubes and springs , by which every purpose of protection and offence was effectually served . À dagger 's blade was attach- ed to it , capable"),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_4.txt',
#   7714,
#   'was attach- ed to it , capable of being fixed at the end , and of answer- ing the destructive purpose of a bayonet . On his departure from Solebury , my friend left it , as a pledge of'),
#  ('/Users/tunder/Box Sync/NEHproject/dirtynarratives/8223_4.txt',
#   8240,
#   'threw myself into this cavity . I discovered , in an instant , that is was totally unfit for my purpose , but it was too late to repair my miscarriage . This wall of the hovel was placed near')]
